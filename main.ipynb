# %% [markdown]
# <a href="https://colab.research.google.com/github/pathakmohit/Datascience_cybercrime_analytics/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets


score = pd.read_csv('score.csv')
score.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
df = pd.DataFrame(score)
print(df)
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (25, 2)

# %%
df.corr()
# Out:
#            Hours    Scores
# Hours   1.000000  0.976191
# Scores  0.976191  1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Hours'].plot(kind='hist', bins=20, title='Hours')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Scores'].plot(kind='hist', bins=20, title='Scores')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='Hours', y='Scores', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
# ...

# %%
df.hist(figsize=(10,10))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# prompt: create boxplot

import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
sns.boxplot(data=df)
plt.show()

# %%
import scipy.stats as stats
z = np.abs(stats.zscore(df))
print(z)
# Out:
#        Hours    Scores
# 0   1.015328  1.230223
# 1   0.035569  0.180820
# 2   0.732394  0.988053
# 3   1.409819  0.949306
# 4   0.611137  0.866968
# 5   1.419519  1.270585
# 6   1.692753  1.474008
# 7   0.197245  0.343881
# 8   1.328981  1.191476
# 9   0.934490  1.068777
# 10  1.086466  1.352923
# 11  0.358922  0.424605
# 12  0.206946  0.422990
# 13  0.691975  0.382629
# 14  1.581196  1.391670
# 15  1.571495  1.756539
# 16  1.015328  0.866968
# 17  1.257843  1.109138
# 18  0.439760  0.626413
# 19  0.965209  0.707136
# 20  0.934490  0.866968
# 21  0.085689  0.101711
# 22  0.489880  0.665160
# 23  0.763113  0.989668
# 24  1.126885  1.393284

# %%
df.count()
# Out:
# Hours     25
# Scores    25
# dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Hours',y='Scores',data=df)
plt.title('Scatterplot of Hours vs score')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.show()

# %% [markdown]
# *This scatter plot shows a positive linear relationship between hours studied and exam score , Indicating that as the number of
#  This code creates a scatter plot using Seaborn to visualize the relationship
#  between the number of hours studied ('Hours') and the corresponding exam scores ('Scores').
# It sets the figure size for better visualization and adds a title, x-label, and y-label
#  to the plot for clarity. Finally, it displays the plot using plt.show().
#  The scatter plot is a useful tool to observe the correlation between two variables.
#  In this case, it helps to understand how the number of hours studied might influence exam scores.
# *

# %%
corelation=df['Hours'].corr(df['Scores'])
print(corelation)
# Out:
# 0.9761906560220887

# %% [markdown]
# The correlation

# %%
correlation_matrix = df.corr()
color =sns.color_palette("Spectral", as_cmap=True)
plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix,annot=True,cmap=color)
plt.title('Correlation Heatmap with custom color')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['Hours']], df['Scores'], test_size=0.2, random_state=42)
print('x train shape')
print(X_train)
print('x test shape')
print(X_test)
print('y train shape')
print(y_train)
print('y test shape')
print(y_test)
# Out:
# x train shape
#     Hours
# 9     2.7
# 13    3.3
# 1     5.1
# 22    3.8
# 5     1.5
# 2     3.2
# 12    4.5
# 15    8.9
# 3     8.5
# 4     3.5
# 20    2.7
# 17    1.9
# 21    4.8
# 18    6.1
# 24    7.8
# 7     5.5
# 10    7.7
# 14    1.1
# 19    7.4
# 6     9.2
# x test shape
#     Hours
# 8     8.3
# 16    2.5
# 0     2.5
# 23    6.9
# 11    5.9
# y train shape
# 9     25
# 13    42
# 1     47
# 22    35
# 5     20
# 2     27
# 12    41
# 15    95
# 3     75
# 4     30
# 20    30
# 17    24
# 21    54
# 18    67
# 24    86
# 7     60
# 10    85
# 14    17
# 19    69
# 6     88
# Name: Scores, dtype: int64
# y test shape
# 8     81
# 16    30
# 0     21
# 23    76
# 11    62
# Name: Scores, dtype: int64
